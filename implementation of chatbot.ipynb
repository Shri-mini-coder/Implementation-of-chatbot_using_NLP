# %%
# !pip install nltk scikit-learn streamlit
import nltk

# %%
#Importing necessary libraries
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl.create_default_https_contex=ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Srinithi
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        'tag': 'greeting',
        'patterns': ['Hi', 'Hello', 'Hey', 'What’s up?', 'How are you?', 'Greetings', 'Good morning', 'Good evening'],
        'responses': ['Hello!', 'Hey there!', 'Hi!', 'Greetings!', 'How can I assist you today?']
    },
    {
        'tag': 'goodbye',
        'patterns': ['Bye', 'See you later', 'Goodbye', 'Take care', 'Catch you later', 'Have a good day'],
        'responses': ['Goodbye!', 'See you soon!', 'Take care!', 'Have a great day!', 'Looking forward to our next chat!']
    },
    {
        'tag': 'thanks',
        'patterns': ['Thank you', 'Thanks', 'Thanks a lot', 'I appreciate it', 'Many thanks', 'Much appreciated'],
        'responses': ['You’re welcome!', 'Anytime!', 'No problem!', 'Glad I could help!', 'Happy to assist!']
    },
    {
        'tag': 'about',
        'patterns': ['Who are you?', 'What are you?', 'What’s your purpose?', 'Tell me about yourself'],
        'responses': [
            "I'm an AI-powered chatbot here to assist you!",
            "I can answer questions and provide helpful information.",
            "I’m a chatbot designed to assist with various topics. How can I help?"
        ]
    },
    {
        'tag': 'help',
        'patterns': ['Help', 'I need help', 'Can you help me?', 'What should I do?', 'Assist me'],
        'responses': [
            "Of course! What do you need help with?",
            "I'm here to assist. Please tell me what you're looking for.",
            "Sure! Let me know how I can help."
        ]
    },
    {
        'tag': 'age',
        'patterns': ['How old are you?', 'What’s your age?', 'When were you created?'],
        'responses': [
            "I don’t have an age, but I was created recently in the digital world.",
            "Age is just a number! But I'm as old as the internet, metaphorically speaking.",
            "I exist outside of time! But I'm always learning new things."
        ]
    },
    {
        'tag': 'weather',
        'patterns': ['What’s the weather like?', 'How’s the weather today?', 'Is it hot outside?', 'Do you know today’s weather?'],
        'responses': [
            "I can’t fetch real-time weather, but you can check a weather website or app.",
            "I'm not connected to real-time weather services. Try checking a weather forecast site.",
            "You might want to look up the weather using a weather app for accurate details!"
        ]
    },
    {
        'tag': 'budget',
        'patterns': ['How can I make a budget?', 'What’s a good budgeting strategy?', 'How do I create a budget?', 'Tips for saving money'],
        'responses': [
            "A good budgeting strategy is the 50/30/20 rule: 50% for needs, 30% for wants, 20% for savings.",
            "Start by tracking your income and expenses, then allocate funds wisely for savings and essentials.",
            "Create a budget by setting financial goals, tracking expenses, and adjusting based on priorities."
        ]
    },
    {
        'tag': 'credit_score',
        'patterns': ['What is a credit score?', 'How do I check my credit score?', 'How can I improve my credit score?'],
        'responses': [
            "A credit score represents your financial trustworthiness, helping lenders decide if they can offer you credit.",
            "You can check your credit score through services like Credit Karma, Experian, or your bank's app.",
            "To improve your credit score, pay bills on time, keep credit usage low, and maintain a long credit history."
        ]
    },
    {
        'tag': 'jokes',
        'patterns': ['Tell me a joke', 'Make me laugh', 'Do you know any jokes?'],
        'responses': [
            "Why don’t programmers like nature? Too many bugs! 😂",
            "Why did the chatbot break up with its partner? It needed more space! 🚀",
            "Why do AI assistants never get lost? Because they always follow the algorithms! 😆"
        ]
    },
    {
        'tag': 'motivation',
        'patterns': ['Motivate me', 'Give me some inspiration', 'I need motivation'],
        'responses': [
            "Believe in yourself! Every expert was once a beginner. Keep pushing forward! 🚀",
            "The only limit to your success is your mindset. Stay positive and keep going! 💪",
            "Success is built on consistency, effort, and never giving up. You got this!"
        ]
    },
    {
        'tag': 'unknown',
        'patterns': [],
        'responses': [
            "I'm not sure how to respond to that. Can you rephrase?",
            "I’m still learning! Could you ask in a different way?",
            "That’s an interesting question! Let me try to find more information on that."
        ]
    }
]
